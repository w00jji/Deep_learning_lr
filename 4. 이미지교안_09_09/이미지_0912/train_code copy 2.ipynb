# %% [markdown]
# # 번호판 학습

# %%
# 데이터셋 출처
# https://universe.roboflow.com/hyunjin/korea-car-license-plate/dataset/2

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RiiNI2YfI3h7h2hItphi")
project = rf.workspace("hyunjin").project("korea-car-license-plate")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Korea-Car-License-Plate-2 in yolov9:: 100%|██████████| 1006/1006 [00:00<00:00, 15111.96it/s]

# %%
#/Korea-Car-License-Plate-2/data.yaml train, val, test path 내용 아래처럼 수정

#train: ./train/images

#val: ./valid/images

#test: ./test/images

# %%
#Model	size (pixels)	mAPval 50-95	mAPval 50	params(M)	FLOPs(B)
#YOLOv9t	640	38.3	53.1	2.0	7.7
#YOLOv9s	640	46.8	63.4	7.2	26.7
#YOLOv9m	640	51.4	68.1	20.1	76.8
#YOLOv9c	640	53.0	70.2	25.5	102.8
#YOLOv9e	640	55.6	72.8	58.1	192.5

# %% [markdown]
# # 학습된 모델 저장 디렉토리는 carplate라는 폴더로 설정.

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov9c.pt')

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data='/home/ohseunghwan/AIproject/Leeyolov9/Korea-Car-License-Plate-2/data.yaml', save=True, epochs=100, imgsz=640,project="carplate")
# Out:
# YOLOv9c summary: 618 layers, 25590912 parameters, 0 gradients, 104.0 GFLOPs
# New https://pypi.org/project/ultralytics/8.2.17 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.27 🚀 Python-3.8.3 torch-1.13.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24259MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
from ultralytics import YOLO
model = YOLO('carplate/train/weights/best.pt')

# valid 폴더 안에 있는 모든 이미지들을 추론한 후 ./runs안에 추론 결과 이미지를 저장
result =model.predict(source="/home/ohseunghwan/AIproject/Leeyolov9/test", save=True, imgsz=640)
# Out:
# image 1/5 /home/ohseunghwan/AIproject/Leeyolov9/test/2.JPG: 384x640 1 LicensePlate, 13.8ms
# image 2/5 /home/ohseunghwan/AIproject/Leeyolov9/test/3.JPG: 384x640 1 LicensePlate, 11.1ms
# image 3/5 /home/ohseunghwan/AIproject/Leeyolov9/test/images (1).jpg: 640x544 (no detections), 14.1ms
# image 4/5 /home/ohseunghwan/AIproject/Leeyolov9/test/images.jpg: 448x640 (no detections), 13.8ms
# image 5/5 /home/ohseunghwan/AIproject/Leeyolov9/test/캡처.JPG: 384x640 2 LicensePlates, 10.3ms
# Speed: 1.0ms preprocess, 12.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# # 자동차 컬러 학습 (성능이 그닥 안좋음)

# %%
# https://universe.roboflow.com/cars-mkrbj/carcolor-c8kav/dataset/1

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RiiNI2YfI3h7h2hItphi")
project = rf.workspace("cars-mkrbj").project("carcolor-c8kav")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Carcolor--1 in yolov9:: 100%|██████████| 14532/14532 [00:03<00:00, 4559.47it/s]

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov9c.pt')

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data='/home/ohseunghwan/AIproject/Leeyolov9/Carcolor--1/data.yaml', save=True, epochs=2, imgsz=640, project="imbk")

# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# from ultralytics import YOLO

# # YOLO 모델 로드
# model = YOLO('/home/ohseunghwan/AIproject/Leeyolov9/colordetection/train/weights/best.pt')

# # valid 폴더 안에 있는 모든 이미지들을 추론한 후 ./runs안에 추론 결과 이미지를 저장
# result =model.predict(source="/home/ohseunghwan/AIproject/Leeyolov9/test", save=True, imgsz=640)

# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# from ultralytics import YOLO

# # 사전 정의된 색상
# colors = {
#     (255, 0, 0): "Red",
#     (0, 255, 0): "Green",
#     (0, 0, 255): "Blue",
#     (0, 0, 0): "Black",
#     (255, 255, 255): "White",
#     (255, 255, 0): "Yellow",
#     (0, 255, 255): "Cyan",
#     (255, 0, 255): "Magenta",
# }

# # 밝기를 고려하여 가장 가까운 색상 찾기
# def find_nearest_color(average_color):
#     min_distance = float('inf')
#     nearest_color = ""
#     brightness = np.sqrt(0.299 * (average_color[0] ** 2) + 0.587 * (average_color[1] ** 2) + 0.114 * (average_color[2] ** 2))

#     # 밝기에 따라 색상 판단 기준 변경
#     if brightness < 50:  # 매우 어두운 경우 검정색으로 판단
#         return "Black"

#     for color, name in colors.items():
#         distance = np.sqrt(sum((average_color[i] - color[i]) ** 2 for i in range(3)))
#         if distance < min_distance:
#             min_distance = distance
#             nearest_color = name
#     return nearest_color

# # YOLO 모델 로드
# model = YOLO('/home/ohseunghwan/AIproject/Leeyolov9/colordetection/train/weights/best.pt')

# # 이미지 로드
# image_path = '/home/ohseunghwan/AIproject/Leeyolov9/test/3.JPG'
# image = cv2.imread(image_path)
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# # 객체 탐지 수행
# results = model.predict(image_rgb)

# # 결과 시각화
# plt.figure(figsize=(10, 10))
# plt.imshow(image_rgb)
# plt.axis('off')

# for result in results:
#     boxes = result.boxes
#     for box in boxes:
#         x1, y1, x2, y2 = map(int, box.xyxy[0])
#         label = model.names[int(box.cls[0])]
#         confidence = box.conf[0].item()

#         # 바운딩 박스 내의 이미지 추출
#         cropped_image = image_rgb[y1:y2, x1:x2]

#         # 평균 색상 계산 (RGB 형태로)
#         average_color_rgb = np.mean(cropped_image, axis=(0, 1))

#         # 가장 가까운 색상 찾기
#         color_name = find_nearest_color(average_color_rgb)
#         print(f"Detected object: {label} with color: {color_name} and confidence: {confidence:.2f}")

#         # 바운딩 박스와 레이블을 이미지에 그리기
#         plt.gca().add_patch(plt.Rectangle((x1, y1), x2 - x1, y2 - y1, edgecolor='green', facecolor='none', linewidth=2))
#         plt.text(x1, y1 - 10, f'{label} {color_name} {confidence:.2f}', color='green', fontsize=12, bbox=dict(facecolor='yellow', alpha=0.5))

# # 결과 이미지 출력
# plt.show()

# %% [markdown]
# # 자동차 컬러학습2 (성능 우수)

# %% [markdown]
# #https://universe.roboflow.com/bacque-ia-rdpmm/car-xqgss/dataset/6#

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RiiNI2YfI3h7h2hItphi")
project = rf.workspace("bacque-ia-rdpmm").project("car-xqgss")
version = project.version(6)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to car-6 in yolov9:: 100%|██████████| 1223/1223 [00:00<00:00, 5692.80it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 667.1 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.9/871.9 kB 6.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov9c.pt')

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data='/content/car-6/data.yaml', save=True, epochs=2, imgsz=640, project="imbk")
# Out:
# YOLOv9c summary: 618 layers, 25,590,912 parameters, 0 gradients, 104.0 GFLOPs
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO

# YOLO 모델 로드
model = YOLO('/home/ohseunghwan/AIproject/Leeyolov9/colordetection2/train/weights/best.pt')

# valid 폴더 안에 있는 모든 이미지들을 추론한 후 ./runs안에 추론 결과 이미지를 저장
result =model.predict(source="/home/ohseunghwan/AIproject/Leeyolov9/test", save=True, imgsz=640,conf=0.6)
# Out:
# image 1/5 /home/ohseunghwan/AIproject/Leeyolov9/test/2.JPG: 384x640 1 black, 10.5ms
# image 2/5 /home/ohseunghwan/AIproject/Leeyolov9/test/3.JPG: 384x640 1 white, 12.0ms
# image 3/5 /home/ohseunghwan/AIproject/Leeyolov9/test/images (1).jpg: 640x544 1 white, 10.8ms
# image 4/5 /home/ohseunghwan/AIproject/Leeyolov9/test/images.jpg: 448x640 1 white, 10.4ms
# image 5/5 /home/ohseunghwan/AIproject/Leeyolov9/test/캡처.JPG: 384x640 1 grey, 10.2ms
# Speed: 0.8ms preprocess, 10.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2

# %%
# 잡힌 클래스 출력
for detection in result[0].boxes:  # 첫 번째 이미지에 대한 예측 결과
    class_id = int(detection.cls)  # 클래스 ID
    confidence = detection.conf  # 신뢰도
    class_name = model.names[class_id]  # 클래스 이름 얻기
    print(f"Class ID: {class_id}, Class Name: {class_name}, Confidence: {confidence}")
# Out:
# Class ID: 0, Class Name: black, Confidence: tensor([0.8926], device='cuda:0')
